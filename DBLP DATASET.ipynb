# %%
import pandas as pd

# %%
df1 = pd.read_excel('Muthu2013.xlsx')
print (df1.head())
# Out:
#      JOURNAL                                              PAPER  \
# 0  Acta Inf.  Verifying a simplification of mutual exclusion...
# 1  Acta Inf.  Verification of asynchronous systems with an u...
# 2  Acta Inf.  Trace- and failure-based semantics for respons...
# 3  Acta Inf.  Disjunctivity and other properties of sets of ...
# 4  Acta Inf.  Special issue on "Combining Compositionality a...
#
#                AUTHOR  YEAR                                        URL  \
# 0    Wim H. Hesselink  2013  https://doi.org/10.1007/s00236-006-0023-y
# 1     Ramtin Khosravi  2019         https://doi.org/10.1007/BF01178582
# 2           ller 0001  2014  https://doi.org/10.1007/s00236-002-0097-0
# 3  Manasi S. Kulkarni  2017      https://doi.org/10.1007/s002360050178
# 4       diger Olderog  2015         https://doi.org/10.1007/BF01213078
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# ...

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('Muthu2013.xlsx')
df = pd.DataFrame(df1, columns = ['JOURNALS', 'PAPER', 'AUTHOR', 'YEAR', 'URL'])
print (df)
# Out:
#         JOURNALS                                              PAPER  \
# 0            NaN  Verifying a simplification of mutual exclusion...
# 1            NaN  Verification of asynchronous systems with an u...
# 2            NaN  Trace- and failure-based semantics for respons...
# 3            NaN  Disjunctivity and other properties of sets of ...
# 4            NaN  Special issue on "Combining Compositionality a...
# 5            NaN  Efficient controller synthesis for a fragment ...
# 6            NaN  Compositional schedulability analysis of real-...
# 7            NaN              Negotiation as concurrency primitive.
# 8            NaN  Efficient execution of dynamically controllabl...
# 9            NaN  Probabilistic bisimulation for realistic sched...
# 10           NaN  State complexity of deletion and bipolar delet...
# 11           NaN  Symbolic checking of Fuzzy CTL on Fuzzy Progra...
# 12           NaN           Regular and context-free nominal traces.
# ...

# %%
df1.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [JOURNAL, PAPER, AUTHOR, YEAR, URL, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11]
# Index: []

# %%
df.dropna(thresh=4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-c2bb11e793a2> in <module>
# ----> 1 df.dropna(thresh=4)
#
# AttributeError: module 'pandas' has no attribute 'dropna'

# %%
df.dropna(subset=['YEAR'])
# Out:
#         JOURNALS                                              PAPER  \
# 0            NaN  Verifying a simplification of mutual exclusion...
# 1            NaN  Verification of asynchronous systems with an u...
# 2            NaN  Trace- and failure-based semantics for respons...
# 3            NaN  Disjunctivity and other properties of sets of ...
# 4            NaN  Special issue on "Combining Compositionality a...
# 5            NaN  Efficient controller synthesis for a fragment ...
# 6            NaN  Compositional schedulability analysis of real-...
# 7            NaN              Negotiation as concurrency primitive.
# 8            NaN  Efficient execution of dynamically controllabl...
# 9            NaN  Probabilistic bisimulation for realistic sched...
# 10           NaN  State complexity of deletion and bipolar delet...
# 11           NaN  Symbolic checking of Fuzzy CTL on Fuzzy Progra...
# 12           NaN           Regular and context-free nominal traces.
# ...
